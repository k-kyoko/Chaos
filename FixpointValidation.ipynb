# %%
#  20180524
#　logisticモデルと三次関数の源点と沈点を識別してそれをグラフに書き込む

using ForwardDiff
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
x_0 = 0.01
f(x) = 2x*(1-x)
g(x) = (3x - x^3) / 2

# x_fを適用した回数
x_1 = f(x_0)
x_2 = f(x_1)
# 微分係数
fd_1 = x_1 / x_0
fd_2 = x_2 / x_1
# Out:
# 1.9604

# %%
fd_0 = ForwardDiff.derivative(f,0)

errate1 = (fd_1 - fd_0) / fd_0 *100
errate2 = (fd_2 - fd_0) / fd_0 *100

println(errate1)
println(errate2)

# 誤差率１％位なので一致と考えて良い

println("""TheoricalValue:$fd_0,
           Value:$fd_1,
           ErrorRate:$(round(100(fd_1 - fd_0)/ fd_0,5))%""")
#5がないと整数切り
# """はdoc string　改行込の文字列を扱える
# $はtemplate literal 参照と文字列埋め込む変換(cast)したものを文字列に埋め込む
# Out:
# -0.9999999999999898
# -1.980000000000004
# TheoricalValue:2,
# Value:1.9800000000000002,
# ErrorRate:-1.0%

# %%
#始点と終点が同じグラフを書いて点に対して丸のマーカーが振られるようにする
# logistic model f(x)=2x*(1-x)

Domein = [0.01i for i=0:100]
Range = [f(i) for i in Domein]

plot(Domein, Range, label=["f(x)=2x*(1-x)"],lw = 2)

# x=0,1/2においての微分係数を算出. fd(f,x)>1 or <1 で判別

fd(f,x) = ForwardDiff.derivative(f,x)

for i in [0,1/2]
  if fd(f,i) > 1
  l = "source point"
    elseif fd(f,i) < 1
    l = "sink point"
  end
  
  plot!([i,i],[f(i),f(i)],label = l,marker=:circle) 
   
 end
plot!()
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip6000">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6001">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6000)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6002">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.0141,363.094 55.0141,13.2835
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   185.381,363.094 185.381,13.2835
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   315.748,363.094 315.748,13.2835
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   446.115,363.094 446.115,13.2835
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   576.482,363.094 576.482,13.2835
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,358.297 583.835,358.297
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,290.254 583.835,290.254
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,222.211 583.835,222.211
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,154.167 583.835,154.167
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,86.1239 583.835,86.1239
#   "/>
# <polyline clip-path="url(#clip6002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,18.0805 583.835,18.0805
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 592.126,368.504
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.0141,368.504 55.0141,363.094
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   185.381,368.504 185.381,363.094
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.748,368.504 315.748,363.094
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   446.115,368.504 446.115,363.094
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   576.482,368.504 576.482,363.094
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,358.297 47.6614,358.297
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,290.254 47.6614,290.254
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,222.211 47.6614,222.211
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,154.167 47.6614,154.167
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,86.1239 47.6614,86.1239
#   "/>
# <polyline clip-path="url(#clip6000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,18.0805 47.6614,18.0805
#   "/>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 55.0141, 382.304)" x="55.0141" y="382.304">0.00</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 185.381, 382.304)" x="185.381" y="382.304">0.25</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.748, 382.304)" x="315.748" y="382.304">0.50</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 446.115, 382.304)" x="446.115" y="382.304">0.75</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 576.482, 382.304)" x="576.482" y="382.304">1.00</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 362.797)" x="33.3701" y="362.797">0.0</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 294.754)" x="33.3701" y="294.754">0.1</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 226.711)" x="33.3701" y="226.711">0.2</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 158.667)" x="33.3701" y="158.667">0.3</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 90.6239)" x="33.3701" y="90.6239">0.4</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 22.5805)" x="33.3701" y="22.5805">0.5</text>
# </g>
# <polyline clip-path="url(#clip6002)" style="stroke:#009af9; stroke-width:2; stroke-opacity:1; fill:none" points="
#   55.0141,358.297 60.2288,344.825 65.4435,331.624 70.6581,318.696 75.8728,306.04 81.0875,293.656 86.3022,281.544 91.5169,269.705 96.7315,258.138 101.946,246.842
#   107.161,235.819 112.376,225.068 117.59,214.59 122.805,204.383 128.02,194.449 133.234,184.787 138.449,175.397 143.664,166.279 148.878,157.433 154.093,148.86
#   159.308,140.559 164.522,132.529 169.737,124.773 174.952,117.288 180.166,110.075 185.381,103.135 190.596,96.4665 195.81,90.0704 201.025,83.9465

# %%
# 三次関数　g(x) = (3x - x^3) / 2

Domein = [0.01i for i=-200:200]
Range = [g(i) for i in Domein]

plot(Domein, Range, label = "g(x)=(3x-x^3)/2")

fd(g,x) = ForwardDiff.derivative(g,x)

for i in [0,1,-1]
  if fd(g,i) > 1
  l = "source point"
    elseif fd(g,i) < 1
    l = "sink point"
  end
  
  plot!([i,i], [g(i),g(i)], label = l, marker=:circle) 
   
 end
plot!()
# Out:
# WARNING: Method definition fd(Any, Any) in module Main at In[4]:11 overwritten at In[5]:8.
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip6100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6100)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6102">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.0141,363.094 55.0141,13.2835
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   185.381,363.094 185.381,13.2835
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   315.748,363.094 315.748,13.2835
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   446.115,363.094 446.115,13.2835
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   576.482,363.094 576.482,13.2835
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,358.297 583.835,358.297
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,273.243 583.835,273.243
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,188.189 583.835,188.189
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,103.135 583.835,103.135
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,18.0805 583.835,18.0805
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 592.126,368.504
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.0141,368.504 55.0141,363.094
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   185.381,368.504 185.381,363.094
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.748,368.504 315.748,363.094
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   446.115,368.504 446.115,363.094
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   576.482,368.504 576.482,363.094
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,358.297 47.6614,358.297
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,273.243 47.6614,273.243
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,188.189 47.6614,188.189
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,103.135 47.6614,103.135
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,18.0805 47.6614,18.0805
#   "/>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 55.0141, 382.304)" x="55.0141" y="382.304">-2</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 185.381, 382.304)" x="185.381" y="382.304">-1</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.748, 382.304)" x="315.748" y="382.304">0</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 446.115, 382.304)" x="446.115" y="382.304">1</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 576.482, 382.304)" x="576.482" y="382.304">2</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 362.797)" x="33.3701" y="362.797">-1.0</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 277.743)" x="33.3701" y="277.743">-0.5</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 192.689)" x="33.3701" y="192.689">0.0</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 107.635)" x="33.3701" y="107.635">0.5</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 22.5805)" x="33.3701" y="22.5805">1.0</text>
# </g>
# <polyline clip-path="url(#clip6102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.0141,18.0805 56.3178,25.6845 57.6215,33.1868 58.9251,40.5882 60.2288,47.889 61.5325,55.0897 62.8361,62.191 64.1398,69.1933 65.4435,76.097 66.7471,82.9028
#   68.0508,89.6111 69.3545,96.2225 70.6581,102.737 71.9618,109.156 73.2655,115.48 74.5692,121.708 75.8728,127.843 77.1765,133.883 78.4802,139.83 79.7838,145.684
#   81.0875,151.446 82.3912,157.115 83.6948,162.694 84.9985,168.181 86.3022,173.579 87.6059,178.886 88.9095,184.104 90.2132,189.234 91.5169,194.275 92.8205,199.228
#   94.1242,204.094 95.4279,208.873 96.7315,213.566 98.0352,218.174 99.3389,222.696 100.643,227.133 101.946,231.486 103.25,235.756 104.554,239.942 105.857,244.046
#   107.161,248.067 108.465,252.007 109.768,255.866 111.072,259.644 112.376,263.342 113.679,266.96 114.983,270.499 116.287,273.96 117.59,277.342 118.894,280.647
#   120.198,283.875 121.501,287.026 122.805,290.102 124.109,293.101 125.412,296.026 126.716,298.876 128.02,301.653 129.323,304.355 130.627,306.985 131.931,309.543
#   133.234,312.028 134.538,314.442 135.842,316.785 137.145,319.057 138.449,321.26 139.
